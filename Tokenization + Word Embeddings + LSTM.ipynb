# %% [markdown]
# # 1- Imports

# %%
import numpy as np 
import pandas as pd 
import re
import string
import nltk
from nltk.corpus import stopwords
from collections import Counter
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow import keras
from tensorflow.keras import layers

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
train.shape
# Out:
# (7613, 5)

# %%
print((train.target == 1).sum()) # Disaster
print((train.target == 0).sum()) # No Disaster
# Out:
# 3271
# 4342

# %% [markdown]
# # 2- Preprocessing

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_URL(text):
    url = re.compile(r"https?://\S+|www\.\S+")
    return url.sub(r"", text)

def remove_punct(text):
    translator = str.maketrans("", "", string.punctuation)
    return text.translate(translator)

# %%
#regex pattern to remove links
pattern = re.compile(r"https?://(\S+|www)\.\S+")
#for train
for t in train.text:
    matches = pattern.findall(t)
    for match in matches:
        print(t)
        print('After Transformation:')
        print(pattern.sub(r"", t))
    if len(matches) > 0:
        break
# Out:
# @bbcmtd Wholesale Markets ablaze http://t.co/lHYXEOHY6C
# After Transformation:
# @bbcmtd Wholesale Markets ablaze

# %%
#for test:
for t in test.text:
    matches = pattern.findall(t)
    for match in matches:
        print(t)
        print('After Transformation:')
        print(pattern.sub(r"", t))
    if len(matches) > 0:
        break
# Out:
# Birmingham Wholesale Market is ablaze BBC News - Fire breaks out at Birmingham's Wholesale Market http://t.co/irWqCEZWEU
# After Transformation:
# Birmingham Wholesale Market is ablaze BBC News - Fire breaks out at Birmingham's Wholesale Market

# %%
#preprocess data frames:
#train
train["text"] = train.text.map(remove_URL) 
train["text"] = train.text.map(remove_punct)
#test
test["text"] = test.text.map(remove_URL) 
test["text"] = test.text.map(remove_punct)

# %%
# remove stopwords
nltk.download('stopwords')

stop = set(stopwords.words("english"))

def remove_stopwords(text):
    filtered_words = [word.lower() for word in text.split() if word.lower() not in stop]
    return " ".join(filtered_words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
stop
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
#train
train["text"] = train.text.map(remove_stopwords)
#test
test["text"] = test.text.map(remove_stopwords)

# %%
#Check
train.text
# Out:
# 0            deeds reason earthquake may allah forgive us
# 1                   forest fire near la ronge sask canada
# 2       residents asked shelter place notified officer...
# 3       13000 people receive wildfires evacuation orde...
# 4       got sent photo ruby alaska smoke wildfires pou...
#                               ...
# 7608    two giant cranes holding bridge collapse nearb...
# 7609    ariaahrary thetawniest control wild fires cali...
# 7610                      m194 0104 utc5km volcano hawaii
# 7611    police investigating ebike collided car little...
# 7612    latest homes razed northern california wildfir...
# Name: text, Length: 7613, dtype: object

# %%
# Count unique words
def counter_word(text_col):
    count = Counter()
    for text in text_col.values:
        for word in text.split():
            count[word] += 1
    return count


counter = counter_word(train.text)

# %%
len(counter)
# Out:
# 17971

# %%
# counter

# %%
counter.most_common(5)
# Out:
# [('like', 345), ('im', 299), ('amp', 298), ('fire', 250), ('get', 229)]

# %%
num_unique_words = len(counter)
num_unique_words
# Out:
# 17971

# %%
# Split dataset into training and validation set
X = train.text
y = train.target
train_sentences, val_sentences , train_labels, val_labels = train_test_split(X, y, test_size=0.2)

# %%
#train/val
train_sentences = train_sentences.to_numpy()
train_labels = train_labels.to_numpy()
val_sentences = val_sentences.to_numpy()
val_labels = val_labels.to_numpy()

# %%
#test
test_sentences = test.text.to_numpy()

# %%
train_sentences.shape, val_sentences.shape
# Out:
# ((6090,), (1523,))

# %%
# Tokenize
# vectorize a text corpus by turning each text into a sequence of integers

tokenizer = Tokenizer(num_words=num_unique_words)
tokenizer.fit_on_texts(train_sentences) # fit only to training

# %%
# Now each word has unique index
word_index = tokenizer.word_index
word_index
# Out:
# {'like': 1,
#  'amp': 2,
#  'im': 3,
#  'get': 4,
#  'fire': 5,
#  'via': 6,
#  'new': 7,
#  'people': 8,
#  'one': 9,
#  'news': 10,
#  'dont': 11,
#  'video': 12,
#  '2': 13,
#  'us': 14,
#  'emergency': 15,
#  'disaster': 16,
#  'would': 17,
#  'still': 18,
#  'suicide': 19,
#  'police': 20,
#  'back': 21,
#  'storm': 22,
#  'man': 23,
#  'body': 24,
#  'crash': 25,
#  'know': 26,
#  'first': 27,
#  'day': 28,
#  'bomb': 29,
#  'got': 30,
#  'california': 31,
#  'burning': 32,
#  'buildings': 33,
#  'world': 34,
#  'time': 35,
#  'rt': 36,
#  'youtube': 37,
#  'see': 38,
#  'fires': 39,
#  'dead': 40,
#  'going': 41,
#  'nuclear': 42,
#  'attack': 43,
#  '3': 44,
#  'love': 45,
#  'two': 46,
#  'cant': 47,
#  'train': 48,
#  'think': 49,
#  'families': 50,
#  'life': 51,
#  'killed': 52,
#  'go': 53,
#  'hiroshima': 54,
#  'u': 55,
#  'many': 56,
#  'good': 57,
#  'could': 58,
#  'war': 59,
#  'may': 60,
#  'today': 61,
#  'watch': 62,
#  'way': 63,
#  'car': 64,
#  'years': 65,
#  'full': 66,
#  'accident': 67,
#  'say': 68,
#  'want': 69,
#  'last': 70,
#  'work': 71,
#  'make': 72,
#  'collapse': 73,
#  'year': 74,
#  'mass': 75,
#  'even': 76,
#  'lol': 77,
#  'need': 78,
#  'fatal': 79,
#  '5': 80,
#  'death': 81,
#  'help': 82,
#  'pm': 83,
#  'wreck': 84,
#  'right': 85,
#  'mh370': 86,
#  'look': 87,
#  'army': 88,
#  'really': 89,
#  'youre': 90,
#  'bombing': 91,
#  'best': 92,
#  'much': 93,
#  '4': 94,
#  'take': 95,
#  'let': 96,
#  'forest': 97,
#  'another': 98,
#  'home': 99,
#  'school': 100,
#  'bomber': 101,
#  '1': 102,
#  'please': 103,
#  'city': 104,
#  'thats': 105,
#  'obama': 106,
#  'legionnaires': 107,
#  'everyone': 108,
#  'northern': 109,
#  'wildfire': 110,
#  'old': 111,
#  'shit': 112,
#  'since': 113,
#  'never': 114,
#  'feel': 115,
#  'top': 116,
#  'said': 117,
#  'military': 118,
#  'oil': 119,
#  'ever': 120,
#  'fear': 121,
#  'read': 122,
#  'black': 123,
#  'latest': 124,
#  'homes': 125,
#  'flood': 126,
#  'flames': 127,
#  'ass': 128,
#  'hot': 129,
#  'live': 130,
#  '2015': 131,
#  'near': 132,
#  'atomic': 133,
#  'every': 134,
#  'injured': 135,
#  'times': 136,
#  'great': 137,
#  'hit': 138,
#  'weather': 139,
#  'getting': 140,
#  'god': 141,
#  'water': 142,
#  'hope': 143,
#  'state': 144,
#  'floods': 145,
#  'truck': 146,
#  'come': 147,
#  'next': 148,
#  'smoke': 149,
#  'flooding': 150,
#  'content': 151,
#  '\x89û': 152,
#  'loud': 153,
#  'damage': 154,
#  'face': 155,
#  'always': 156,
#  'coming': 157,
#  'without': 158,
#  'malaysia': 159,
#  'japan': 160,
#  'cause': 161,
#  'stop': 162,
#  'plan': 163,
#  'bad': 164,
#  'evacuation': 165,
#  'boy': 166,
#  'spill': 167,
#  'debris': 168,
#  'free': 169,
#  'thunderstorm': 170,
#  'movie': 171,
#  'food': 172,
#  'confirmed': 173,
#  'bags': 174,
#  'heat': 175,
#  'made': 176,
#  'set': 177,
#  'well': 178,
#  'cross': 179,
#  'liked': 180,
#  'severe': 181,
#  'sinking': 182,
#  'panic': 183,
#  'hes': 184,
#  'theres': 185,
#  'found': 186,
#  'wind': 187,
#  'thunder': 188,
#  'rain': 189,
#  'hail': 190,
#  'earthquake': 191,
#  'destroy': 192,
#  'charged': 193,
#  'air': 194,
#  'evacuate': 195,
#  'natural': 196,
#  'high': 197,
#  'fall': 198,
#  'looks': 199,
#  'end': 200,
#  'attacked': 201,
#  'derailment': 202,
#  'bloody': 203,
#  'fucking': 204,
#  'services': 205,
#  'save': 206,
#  'night': 207,
#  'weapons': 208,
#  'warning': 209,
#  'wrecked': 210,
#  'put': 211,
#  'failure': 212,
#  'murder': 213,
#  'head': 214,
#  'whole': 215,
#  'story': 216,
#  'little': 217,
#  'service': 218,
#  'released': 219,
#  'injuries': 220,
#  'report': 221,
#  'weapon': 222,
#  'lightning': 223,
#  'breaking': 224,
#  'area': 225,
#  'hurricane': 226,
#  'road': 227,
#  'blood': 228,
#  'desolation': 229,
#  'wild': 230,
#  'check': 231,
#  'away': 232,
#  'someone': 233,
#  'summer': 234,
#  'reddit': 235,
#  '70': 236,
#  'post': 237,
#  'catastrophe': 238,
#  'survive': 239,
#  'deaths': 240,
#  'explosion': 241,
#  'says': 242,
#  'keep': 243,
#  'gonna': 244,
#  'lives': 245,
#  'fatalities': 246,
#  'crashed': 247,
#  'house': 248,
#  'outbreak': 249,
#  'rescue': 250,
#  '\x89ûò': 251,
#  'w': 252,
#  'dust': 253,
#  'week': 254,
#  'ill': 255,
#  'run': 256,
#  'violent': 257,
#  'collapsed': 258,
#  'call': 259,
#  'survived': 260,
#  'things': 261,
#  'white': 262,
#  'explode': 263,
#  'drought': 264,
#  'bang': 265,
#  'family': 266,
#  'wreckage': 267,
#  'around': 268,
#  'screaming': 269,
#  'also': 270,
#  'destruction': 271,
#  'trapped': 272,
#  'inundated': 273,
#  'structural': 274,
#  'came': 275,
#  'armageddon': 276,
#  'curfew': 277,
#  'change': 278,
#  'danger': 279,
#  'rescuers': 280,
#  'thing': 281,
#  'derailed': 282,
#  'saudi': 283,
#  'missing': 284,
#  'investigators': 285,
#  'landslide': 286,
#  'ambulance': 287,
#  'blew': 288,
#  'island': 289,
#  'derail': 290,
#  'ive': 291,
#  'county': 292,
#  'burned': 293,
#  'oh': 294,
#  'injury': 295,
#  'something': 296,
#  'trauma': 297,
#  'woman': 298,
#  'migrants': 299,
#  'terrorist': 300,
#  'sunk': 301,
#  'blown': 302,
#  'photo': 303,
#  'quarantined': 304,
#  'saw': 305,
#  'big': 306,
#  'power': 307,
#  'displaced': 308,
#  'sinkhole': 309,
#  'riot': 310,
#  'drowning': 311,
#  'red': 312,
#  'collided': 313,
#  'didnt': 314,
#  'destroyed': 315,
#  'bridge': 316,
#  'demolish': 317,
#  'hellfire': 318,
#  'wave': 319,
#  'real': 320,
#  'fuck': 321,
#  'exploded': 322,
#  'update': 323,
#  'heard': 324,
#  'responders': 325,
#  'rescued': 326,
#  'stock': 327,
#  'wounded': 328,
#  'long': 329,
#  'traumatised': 330,
#  'tragedy': 331,
#  'bus': 332,
#  'ruin': 333,
#  'boat': 334,
#  'blast': 335,
#  'least': 336,
#  '15': 337,
#  'pkk': 338,
#  'detonated': 339,
#  'thank': 340,
#  'catastrophic': 341,
#  'august': 342,
#  'engulfed': 343,
#  'bleeding': 344,
#  'refugees': 345,
#  'sandstorm': 346,
#  'mudslide': 347,
#  'past': 348,
#  'half': 349,
#  'deluge': 350,
#  'terrorism': 351,
#  'cliff': 352,
#  'hazard': 353,
#  'hazardous': 354,
#  '40': 355,
#  'affected': 356,
#  'hostages': 357,
#  'mosque': 358,
#  'quarantine': 359,
#  'twitter': 360,
#  'famine': 361,
#  'id': 362,
#  'ok': 363,
#  'game': 364,
#  'trouble': 365,
#  'crush': 366,
#  'better': 367,
#  'lot': 368,
#  'show': 369,
#  'women': 370,
#  'harm': 371,
#  'wanna': 372,
#  'twister': 373,
#  'tomorrow': 374,
#  'whirlwind': 375,
#  'girl': 376,
#  'isis': 377,
#  'baby': 378,
#  'sure': 379,
#  'apocalypse': 380,
#  'iran': 381,
#  'flattened': 382,
#  'nothing': 383,
#  'plane': 384,
#  'panicking': 385,
#  'heart': 386,
#  'screamed': 387,
#  'hundreds': 388,
#  'detonation': 389,
#  'start': 390,
#  'fedex': 391,
#  'stay': 392,
#  'bag': 393,
#  'casualties': 394,
#  'meltdown': 395,
#  'horrible': 396,
#  'kills': 397,
#  'massacre': 398,
#  'detonate': 399,
#  'went': 400,
#  'cool': 401,
#  'wounds': 402,
#  'officials': 403,
#  'fatality': 404,
#  'evacuated': 405,
#  'hostage': 406,
#  'possible': 407,
#  'rioting': 408,
#  'obliterated': 409,
#  'pandemonium': 410,
#  '16yr': 411,
#  'actually': 412,
#  'thought': 413,
#  'anniversary': 414,
#  'calgary': 415,
#  'collide': 416,
#  'ebay': 417,
#  'phone': 418,
#  'bioterror': 419,
#  'shoulder': 420,
#  'airplane': 421,
#  'tonight': 422,
#  'goes': 423,
#  'part': 424,
#  'caused': 425,
#  'kids': 426,
#  'bush': 427,
#  'group': 428,
#  '20': 429,
#  'drowned': 430,
#  'fan': 431,
#  'words': 432,
#  'suspect': 433,
#  'almost': 434,
#  'collision': 435,
#  'longer': 436,
#  'electrocuted': 437,
#  'traffic': 438,
#  'drown': 439,
#  'turkey': 440,
#  'soon': 441,
#  'demolished': 442,
#  'must': 443,
#  'devastation': 444,
#  'issues': 445,
#  'st': 446,
#  'hijacker': 447,
#  'tornado': 448,
#  'bombed': 449,
#  'reunion': 450,
#  'lets': 451,
#  'children': 452,
#  'lava': 453,
#  'song': 454,
#  'left': 455,
#  'stretcher': 456,
#  'avalanche': 457,
#  'security': 458,
#  'survivors': 459,
#  'volcano': 460,
#  'windstorm': 461,
#  'done': 462,
#  'light': 463,
#  'died': 464,
#  'n': 465,
#  'beautiful': 466,
#  'government': 467,
#  'upheaval': 468,
#  'thanks': 469,
#  'yeah': 470,
#  'chemical': 471,
#  'north': 472,
#  'building': 473,
#  'remember': 474,
#  'pic': 475,
#  'national': 476,
#  'three': 477,
#  'arson': 478,
#  'ur': 479,
#  'airport': 480,
#  'minute': 481,
#  'cyclone': 482,
#  'leave': 483,
#  'obliterate': 484,
#  'kill': 485,
#  'already': 486,
#  'annihilated': 487,
#  'music': 488,
#  'murderer': 489,
#  'bestnaijamade': 490,
#  '9': 491,
#  'sue': 492,
#  'india': 493,
#  'due': 494,
#  'yet': 495,
#  'use': 496,
#  'inside': 497,
#  'screams': 498,
#  'bc': 499,
#  'blazing': 500,
#  'far': 501,
#  'obliteration': 502,
#  'tsunami': 503,
#  'declares': 504,
#  'guys': 505,
#  'market': 506,
#  'manslaughter': 507,
#  'shot': 508,
#  'hijacking': 509,
#  'helicopter': 510,
#  'shooting': 511,
#  'find': 512,
#  'land': 513,
#  'nearby': 514,
#  'peace': 515,
#  'battle': 516,
#  'hijack': 517,
#  'hours': 518,
#  'seismic': 519,
#  'razed': 520,
#  'play': 521,
#  'anything': 522,
#  'site': 523,
#  'line': 524,
#  'wait': 525,
#  '6': 526,
#  'bioterrorism': 527,
#  'men': 528,
#  '\x89ûó': 529,
#  'job': 530,
#  'hear': 531,
#  'crushed': 532,
#  'bigger': 533,
#  'outside': 534,
#  'deluged': 535,
#  'israeli': 536,
#  'send': 537,
#  'fun': 538,
#  'plans': 539,
#  'sirens': 540,
#  'demolition': 541,
#  'history': 542,
#  'tell': 543,
#  'river': 544,
#  'book': 545,
#  'policy': 546,
#  'rainstorm': 547,
#  'care': 548,
#  'islam': 549,
#  'days': 550,
#  'die': 551,
#  'probably': 552,
#  'theyre': 553,
#  'move': 554,
#  'zone': 555,
#  '7': 556,
#  'nowplaying': 557,
#  'bar': 558,
#  're\x89û': 559,
#  'blaze': 560,
#  'media': 561,
#  'finally': 562,
#  'sound': 563,
#  'typhoondevastated': 564,
#  'saipan': 565,
#  'desolate': 566,
#  'yes': 567,
#  'rubble': 568,
#  'projected': 569,
#  'believe': 570,
#  'typhoon': 571,
#  'making': 572,
#  '11yearold': 573,
#  'place': 574,
#  'eyewitness': 575,
#  'swallowed': 576,
#  'feared': 577,
#  'wake': 578,
#  '8': 579,
#  'hell': 580,
#  'name': 581,
#  'brown': 582,
#  'watching': 583,
#  'bagging': 584,
#  'siren': 585,
#  'doesnt': 586,
#  'fight': 587,
#  'course': 588,
#  'lost': 589,
#  'gets': 590,
#  'deal': 591,
#  'business': 592,
#  'person': 593,
#  'reactor': 594,
#  'gun': 595,
#  'rise': 596,
#  'trench': 597,
#  'wont': 598,
#  'major': 599,
#  'horror': 600,
#  'conclusively': 601,
#  'ship': 602,
#  'control': 603,
#  'la': 604,
#  'reuters': 605,
#  'blight': 606,
#  'daily': 607,
#  'gt': 608,
#  'eyes': 609,
#  'used': 610,
#  'youth': 611,
#  'saved': 612,
#  'money': 613,
#  'anyone': 614,
#  'lab': 615,
#  'caught': 616,
#  'pick': 617,
#  'online': 618,
#  'searching': 619,
#  'officer': 620,
#  'casualty': 621,
#  'okay': 622,
#  'needs': 623,
#  'hey': 624,
#  'nearly': 625,
#  'signs': 626,
#  'side': 627,
#  'fast': 628,
#  'others': 629,
#  'refugio': 630,
#  'costlier': 631,
#  'ablaze': 632,
#  'angry': 633,
#  'huge': 634,
#  'crews': 635,
#  'west': 636,
#  'poor': 637,
#  'ago': 638,
#  'aircraft': 639,
#  'effect': 640,
#  '30': 641,
#  'trying': 642,
#  'houses': 643,
#  'team': 644,
#  'cars': 645,
#  'space': 646,
#  'reason': 647,
#  'flash': 648,
#  'usa': 649,
#  'country': 650,
#  'snowstorm': 651,
#  'feeling': 652,
#  'support': 653,
#  'street': 654,
#  'self': 655,
#  'morning': 656,
#  'tv': 657,
#  'aug': 658,
#  'makes': 659,
#  'data': 660,
#  'south': 661,
#  'toddler': 662,
#  'running': 663,
#  '13': 664,
#  '60': 665,
#  'low': 666,
#  'memories': 667,
#  'might': 668,
#  'whats': 669,
#  'flag': 670,
#  'bodies': 671,
#  'womens': 672,
#  '50': 673,
#  'ball': 674,
#  'order': 675,
#  'annihilation': 676,
#  'appears': 677,
#  'transport': 678,
#  'ignition': 679,
#  'knock': 680,
#  '11': 681,
#  'crisis': 682,
#  'everything': 683,
#  'mp': 684,
#  'electrocute': 685,
#  'looking': 686,
#  'totally': 687,
#  'east': 688,
#  'case': 689,
#  '12': 690,
#  'hate': 691,
#  'listen': 692,
#  'taking': 693,
#  'jobs': 694,
#  'russian': 695,
#  'abc': 696,
#  'trains': 697,
#  'win': 698,
#  'isnt': 699,
#  'second': 700,
#  '10': 701,
#  '25': 702,
#  'wrong': 703,
#  'american': 704,
#  'offensive': 705,
#  'amid': 706,
#  'damn': 707,
#  'spot': 708,
#  'blue': 709,
#  'public': 710,
#  'class': 711,
#  'center': 712,
#  'york': 713,
#  'action': 714,
#  'pay': 715,
#  'mph': 716,
#  'lord': 717,
#  'radio': 718,
#  'temple': 719,
#  'leather': 720,
#  'prebreak': 721,
#  'united': 722,
#  'pretty': 723,
#  'shes': 724,
#  'pakistan': 725,
#  'happy': 726,
#  'disea': 727,
#  'friends': 728,
#  'favorite': 729,
#  'closed': 730,
#  'guy': 731,
#  'theater': 732,
#  'nagasaki': 733,
#  'though': 734,
#  'govt': 735,
#  'camp': 736,
#  'till': 737,
#  'rock': 738,
#  'landing': 739,
#  'crazy': 740,
#  'issued': 741,
#  'entire': 742,
#  'photos': 743,
#  'turned': 744,
#  'seen': 745,
#  'chance': 746,
#  'stand': 747,
#  'sorry': 748,
#  'mayhem': 749,
#  'muslims': 750,
#  'picking': 751,
#  'soudelor': 752,
#  '100': 753,
#  'four': 754,
#  'heavy': 755,
#  'gop': 756,
#  'unconfirmed': 757,
#  'neighbours': 758,
#  'banned': 759,
#  'reports': 760,
#  'hard': 761,
#  'ppl': 762,
#  'giant': 763,
#  'health': 764,
#  'view': 765,
#  'download': 766,
#  'hat': 767,
#  'link': 768,
#  'don\x89ûªt': 769,
#  'bbc': 770,
#  'madhya': 771,
#  'pradesh': 772,
#  'aftershock': 773,
#  'climate': 774,
#  'enough': 775,
#  'worst': 776,
#  'literally': 777,
#  'happened': 778,
#  'insurance': 779,
#  'property': 780,
#  'front': 781,
#  'thousands': 782,
#  'alone': 783,
#  'nws': 784,
#  'drive': 785,
#  'green': 786,
#  'wow': 787,
#  'downtown': 788,
#  'hailstorm': 789,
#  'declaration': 790,
#  'friend': 791,
#  'tweet': 792,
#  'date': 793,
#  'businesses': 794,
#  'russia': 795,
#  'mad': 796,
#  'aint': 797,
#  'playing': 798,
#  'upon': 799,
#  'trust': 800,
#  'gave': 801,
#  'seeing': 802,
#  'israel': 803,
#  'fukushima': 804,
#  'christian': 805,
#  'mount': 806,
#  'flight': 807,
#  'waves': 808,
#  'official': 809,
#  'sounds': 810,
#  'bed': 811,
#  'wanted': 812,
#  'couple': 813,
#  'large': 814,
#  'omg': 815,
#  'mop': 816,
#  'beach': 817,
#  'haha': 818,
#  'hollywood': 819,
#  'miners': 820,
#  'texas': 821,
#  'guess': 822,
#  'vehicle': 823,
#  'virgin': 824,
#  'colorado': 825,
#  'child': 826,
#  'moment': 827,
#  'mom': 828,
#  'myanmar': 829,
#  'called': 830,
#  'maybe': 831,
#  'star': 832,
#  'gas': 833,
#  'takes': 834,
#  'following': 835,
#  'wednesday': 836,
#  'thinking': 837,
#  'comes': 838,
#  'added': 839,
#  'town': 840,
#  'cut': 841,
#  'led': 842,
#  'lamp': 843,
#  'gbbo': 844,
#  'talk': 845,
#  'meek': 846,
#  'experts': 847,
#  'dog': 848,
#  'learn': 849,
#  'scared': 850,
#  'b': 851,
#  'london': 852,
#  'vs': 853,
#  'taken': 854,
#  'turn': 855,
#  'pamela': 856,
#  'level': 857,
#  'pakistani': 858,
#  'ladies': 859,
#  'cake': 860,
#  'centre': 861,
#  'film': 862,
#  'likely': 863,
#  'america': 864,
#  'libya': 865,
#  'instead': 866,
#  'pray': 867,
#  'global': 868,
#  'middle': 869,
#  'village': 870,
#  'reported': 871,
#  'reddits': 872,
#  'subreddits': 873,
#  'british': 874,
#  'scene': 875,
#  'hiring': 876,
#  'blizzard': 877,
#  'king': 878,
#  'driver': 879,
#  'germs': 880,
#  'anthrax': 881,
#  'mishaps': 882,
#  'biggest': 883,
#  'arsonist': 884,
#  'true': 885,
#  'series': 886,
#  '05': 887,
#  'ready': 888,
#  'deep': 889,
#  'playlist': 890,
#  'break': 891,
#  'sad': 892,
#  'act': 893,
#  'lady': 894,
#  'financial': 895,
#  'falling': 896,
#  'arent': 897,
#  'told': 898,
#  'idea': 899,
#  'sex': 900,
#  'chinas': 901,
#  'gems': 902,
#  'risk': 903,
#  'potus': 904,
#  'quiz': 905,
#  'saying': 906,
#  'emmerdale': 907,
#  'album': 908,
#  '70th': 909,
#  'china': 910,
#  'mode': 911,
#  'behind': 912,
#  'metal': 913,
#  'waving': 914,
#  'geller': 915,
#  'twelve': 916,
#  'safety': 917,
#  'room': 918,
#  'computers': 919,
#  'early': 920,
#  'hour': 921,
#  'wants': 922,
#  'try': 923,
#  'militants': 924,
#  'fans': 925,
#  'alarm': 926,
#  'awesome': 927,
#  'apollo': 928,
#  'marks': 929,
#  'bayelsa': 930,
#  'working': 931,
#  'truth': 932,
#  'human': 933,
#  'become': 934,
#  'give': 935,
#  'else': 936,
#  'earth': 937,
#  'drake': 938,
#  'escape': 939,
#  'devastated': 940,
#  'young': 941,
#  'france': 942,
#  'indian': 943,
#  'outrage': 944,
#  'former': 945,
#  'tree': 946,
#  'rd': 947,
#  'galactic': 948,
#  'coaches': 949,
#  'eye': 950,
#  'shift': 951,
#  'dance': 952,
#  'party': 953,
#  'wonder': 954,
#  'lake': 955,
#  'international': 956,
#  'miss': 957,
#  'took': 958,
#  'expected': 959,
#  'denver': 960,
#  'cree': 961,
#  'felt': 962,
#  'travel': 963,
#  'board': 964,
#  'niggas': 965,
#  'piece': 966,
#  'across': 967,
#  'hand': 968,
#  'aba': 969,
#  'delivers': 970,
#  'event': 971,
#  'ahead': 972,
#  'marians': 973,
#  'walk': 974,
#  'teen': 975,
#  'walking': 976,
#  'victims': 977,
#  'pain': 978,
#  'japanese': 979,
#  'nigga': 980,
#  'worse': 981,
#  'causes': 982,
#  'serious': 983,
#  'living': 984,
#  'fashion': 985,
#  'means': 986,
#  'patience': 987,
#  'jonathan': 988,
#  'bombs': 989,
#  'cdt': 990,
#  'cnn': 991,
#  'dude': 992,
#  'park': 993,
#  'join': 994,
#  'bring': 995,
#  'internet': 996,
#  'chile': 997,
#  'firefighters': 998,
#  'members': 999,
#  'internally': 1000,
#  ...}

# %%
#apply on train, validation, and test sentences

train_sequences = tokenizer.texts_to_sequences(train_sentences)
val_sequences = tokenizer.texts_to_sequences(val_sentences)
test_sequences = tokenizer.texts_to_sequences(test_sentences)

# %%
#Check
print(train_sentences[10:15])
print(train_sequences[10:15])
# Out:
# ['agreed especially automatic weapons theres legitimate reason needing one argus99 heidia1438'
#  'think akwa ibom don\x89ûªt come uruan demolish buildings exassembly member warns udom emmanuel'
#  'eversafe emergency auto kit weather unsafe hazardous rushhour gridlock jumperca\x89û'
#  'goooooooaaaaaal'
#  'oil gas exploration takes seismic shift gabon somalia bloomberg somalia']
# [[1918, 1662, 1663, 208, 185, 5639, 647, 5640, 9, 5641, 5642], [49, 5643, 5644, 769, 147, 5645, 317, 33, 5646, 2805, 1919, 5647, 5648], [5649, 15, 3707, 1193, 139, 2806, 354, 5650, 3708, 5651], [5652], [119, 833, 1474, 834, 519, 951, 2261, 1664, 3709, 1664]]

# %%
# Pad the sequences to have the same length
max_length = 15 #arbitrary number

train_padded = pad_sequences(train_sequences, maxlen=max_length, padding="post", truncating="post") #post-> 0
val_padded = pad_sequences(val_sequences, maxlen=max_length, padding="post", truncating="post")
test_padded = pad_sequences(test_sequences, maxlen=max_length, padding="post", truncating="post")

# %%
#Check
train_padded.shape, val_padded.shape
# Out:
# ((6090, 15), (1523, 15))

# %%
#Check
train_padded[10]
# Out:
# array([1918, 1662, 1663,  208,  185, 5639,  647, 5640,    9, 5641, 5642,
#           0,    0,    0,    0])

# %%
#Check
print(train_sentences[10])
print(train_sequences[10])
print(train_padded[10])
# Out:
# agreed especially automatic weapons theres legitimate reason needing one argus99 heidia1438
# [1918, 1662, 1663, 208, 185, 5639, 647, 5640, 9, 5641, 5642]
# [1918 1662 1663  208  185 5639  647 5640    9 5641 5642    0    0    0
#     0]

# %%
# flip (key, value)
reverse_word_index = dict([(idx, word) for (word, idx) in word_index.items()])

# %%
#Check
reverse_word_index
# Out:
# {1: 'like',
#  2: 'amp',
#  3: 'im',
#  4: 'get',
#  5: 'fire',
#  6: 'via',
#  7: 'new',
#  8: 'people',
#  9: 'one',
#  10: 'news',
#  11: 'dont',
#  12: 'video',
#  13: '2',
#  14: 'us',
#  15: 'emergency',
#  16: 'disaster',
#  17: 'would',
#  18: 'still',
#  19: 'suicide',
#  20: 'police',
#  21: 'back',
#  22: 'storm',
#  23: 'man',
#  24: 'body',
#  25: 'crash',
#  26: 'know',
#  27: 'first',
#  28: 'day',
#  29: 'bomb',
#  30: 'got',
#  31: 'california',
#  32: 'burning',
#  33: 'buildings',
#  34: 'world',
#  35: 'time',
#  36: 'rt',
#  37: 'youtube',
#  38: 'see',
#  39: 'fires',
#  40: 'dead',
#  41: 'going',
#  42: 'nuclear',
#  43: 'attack',
#  44: '3',
#  45: 'love',
#  46: 'two',
#  47: 'cant',
#  48: 'train',
#  49: 'think',
#  50: 'families',
#  51: 'life',
#  52: 'killed',
#  53: 'go',
#  54: 'hiroshima',
#  55: 'u',
#  56: 'many',
#  57: 'good',
#  58: 'could',
#  59: 'war',
#  60: 'may',
#  61: 'today',
#  62: 'watch',
#  63: 'way',
#  64: 'car',
#  65: 'years',
#  66: 'full',
#  67: 'accident',
#  68: 'say',
#  69: 'want',
#  70: 'last',
#  71: 'work',
#  72: 'make',
#  73: 'collapse',
#  74: 'year',
#  75: 'mass',
#  76: 'even',
#  77: 'lol',
#  78: 'need',
#  79: 'fatal',
#  80: '5',
#  81: 'death',
#  82: 'help',
#  83: 'pm',
#  84: 'wreck',
#  85: 'right',
#  86: 'mh370',
#  87: 'look',
#  88: 'army',
#  89: 'really',
#  90: 'youre',
#  91: 'bombing',
#  92: 'best',
#  93: 'much',
#  94: '4',
#  95: 'take',
#  96: 'let',
#  97: 'forest',
#  98: 'another',
#  99: 'home',
#  100: 'school',
#  101: 'bomber',
#  102: '1',
#  103: 'please',
#  104: 'city',
#  105: 'thats',
#  106: 'obama',
#  107: 'legionnaires',
#  108: 'everyone',
#  109: 'northern',
#  110: 'wildfire',
#  111: 'old',
#  112: 'shit',
#  113: 'since',
#  114: 'never',
#  115: 'feel',
#  116: 'top',
#  117: 'said',
#  118: 'military',
#  119: 'oil',
#  120: 'ever',
#  121: 'fear',
#  122: 'read',
#  123: 'black',
#  124: 'latest',
#  125: 'homes',
#  126: 'flood',
#  127: 'flames',
#  128: 'ass',
#  129: 'hot',
#  130: 'live',
#  131: '2015',
#  132: 'near',
#  133: 'atomic',
#  134: 'every',
#  135: 'injured',
#  136: 'times',
#  137: 'great',
#  138: 'hit',
#  139: 'weather',
#  140: 'getting',
#  141: 'god',
#  142: 'water',
#  143: 'hope',
#  144: 'state',
#  145: 'floods',
#  146: 'truck',
#  147: 'come',
#  148: 'next',
#  149: 'smoke',
#  150: 'flooding',
#  151: 'content',
#  152: '\x89û',
#  153: 'loud',
#  154: 'damage',
#  155: 'face',
#  156: 'always',
#  157: 'coming',
#  158: 'without',
#  159: 'malaysia',
#  160: 'japan',
#  161: 'cause',
#  162: 'stop',
#  163: 'plan',
#  164: 'bad',
#  165: 'evacuation',
#  166: 'boy',
#  167: 'spill',
#  168: 'debris',
#  169: 'free',
#  170: 'thunderstorm',
#  171: 'movie',
#  172: 'food',
#  173: 'confirmed',
#  174: 'bags',
#  175: 'heat',
#  176: 'made',
#  177: 'set',
#  178: 'well',
#  179: 'cross',
#  180: 'liked',
#  181: 'severe',
#  182: 'sinking',
#  183: 'panic',
#  184: 'hes',
#  185: 'theres',
#  186: 'found',
#  187: 'wind',
#  188: 'thunder',
#  189: 'rain',
#  190: 'hail',
#  191: 'earthquake',
#  192: 'destroy',
#  193: 'charged',
#  194: 'air',
#  195: 'evacuate',
#  196: 'natural',
#  197: 'high',
#  198: 'fall',
#  199: 'looks',
#  200: 'end',
#  201: 'attacked',
#  202: 'derailment',
#  203: 'bloody',
#  204: 'fucking',
#  205: 'services',
#  206: 'save',
#  207: 'night',
#  208: 'weapons',
#  209: 'warning',
#  210: 'wrecked',
#  211: 'put',
#  212: 'failure',
#  213: 'murder',
#  214: 'head',
#  215: 'whole',
#  216: 'story',
#  217: 'little',
#  218: 'service',
#  219: 'released',
#  220: 'injuries',
#  221: 'report',
#  222: 'weapon',
#  223: 'lightning',
#  224: 'breaking',
#  225: 'area',
#  226: 'hurricane',
#  227: 'road',
#  228: 'blood',
#  229: 'desolation',
#  230: 'wild',
#  231: 'check',
#  232: 'away',
#  233: 'someone',
#  234: 'summer',
#  235: 'reddit',
#  236: '70',
#  237: 'post',
#  238: 'catastrophe',
#  239: 'survive',
#  240: 'deaths',
#  241: 'explosion',
#  242: 'says',
#  243: 'keep',
#  244: 'gonna',
#  245: 'lives',
#  246: 'fatalities',
#  247: 'crashed',
#  248: 'house',
#  249: 'outbreak',
#  250: 'rescue',
#  251: '\x89ûò',
#  252: 'w',
#  253: 'dust',
#  254: 'week',
#  255: 'ill',
#  256: 'run',
#  257: 'violent',
#  258: 'collapsed',
#  259: 'call',
#  260: 'survived',
#  261: 'things',
#  262: 'white',
#  263: 'explode',
#  264: 'drought',
#  265: 'bang',
#  266: 'family',
#  267: 'wreckage',
#  268: 'around',
#  269: 'screaming',
#  270: 'also',
#  271: 'destruction',
#  272: 'trapped',
#  273: 'inundated',
#  274: 'structural',
#  275: 'came',
#  276: 'armageddon',
#  277: 'curfew',
#  278: 'change',
#  279: 'danger',
#  280: 'rescuers',
#  281: 'thing',
#  282: 'derailed',
#  283: 'saudi',
#  284: 'missing',
#  285: 'investigators',
#  286: 'landslide',
#  287: 'ambulance',
#  288: 'blew',
#  289: 'island',
#  290: 'derail',
#  291: 'ive',
#  292: 'county',
#  293: 'burned',
#  294: 'oh',
#  295: 'injury',
#  296: 'something',
#  297: 'trauma',
#  298: 'woman',
#  299: 'migrants',
#  300: 'terrorist',
#  301: 'sunk',
#  302: 'blown',
#  303: 'photo',
#  304: 'quarantined',
#  305: 'saw',
#  306: 'big',
#  307: 'power',
#  308: 'displaced',
#  309: 'sinkhole',
#  310: 'riot',
#  311: 'drowning',
#  312: 'red',
#  313: 'collided',
#  314: 'didnt',
#  315: 'destroyed',
#  316: 'bridge',
#  317: 'demolish',
#  318: 'hellfire',
#  319: 'wave',
#  320: 'real',
#  321: 'fuck',
#  322: 'exploded',
#  323: 'update',
#  324: 'heard',
#  325: 'responders',
#  326: 'rescued',
#  327: 'stock',
#  328: 'wounded',
#  329: 'long',
#  330: 'traumatised',
#  331: 'tragedy',
#  332: 'bus',
#  333: 'ruin',
#  334: 'boat',
#  335: 'blast',
#  336: 'least',
#  337: '15',
#  338: 'pkk',
#  339: 'detonated',
#  340: 'thank',
#  341: 'catastrophic',
#  342: 'august',
#  343: 'engulfed',
#  344: 'bleeding',
#  345: 'refugees',
#  346: 'sandstorm',
#  347: 'mudslide',
#  348: 'past',
#  349: 'half',
#  350: 'deluge',
#  351: 'terrorism',
#  352: 'cliff',
#  353: 'hazard',
#  354: 'hazardous',
#  355: '40',
#  356: 'affected',
#  357: 'hostages',
#  358: 'mosque',
#  359: 'quarantine',
#  360: 'twitter',
#  361: 'famine',
#  362: 'id',
#  363: 'ok',
#  364: 'game',
#  365: 'trouble',
#  366: 'crush',
#  367: 'better',
#  368: 'lot',
#  369: 'show',
#  370: 'women',
#  371: 'harm',
#  372: 'wanna',
#  373: 'twister',
#  374: 'tomorrow',
#  375: 'whirlwind',
#  376: 'girl',
#  377: 'isis',
#  378: 'baby',
#  379: 'sure',
#  380: 'apocalypse',
#  381: 'iran',
#  382: 'flattened',
#  383: 'nothing',
#  384: 'plane',
#  385: 'panicking',
#  386: 'heart',
#  387: 'screamed',
#  388: 'hundreds',
#  389: 'detonation',
#  390: 'start',
#  391: 'fedex',
#  392: 'stay',
#  393: 'bag',
#  394: 'casualties',
#  395: 'meltdown',
#  396: 'horrible',
#  397: 'kills',
#  398: 'massacre',
#  399: 'detonate',
#  400: 'went',
#  401: 'cool',
#  402: 'wounds',
#  403: 'officials',
#  404: 'fatality',
#  405: 'evacuated',
#  406: 'hostage',
#  407: 'possible',
#  408: 'rioting',
#  409: 'obliterated',
#  410: 'pandemonium',
#  411: '16yr',
#  412: 'actually',
#  413: 'thought',
#  414: 'anniversary',
#  415: 'calgary',
#  416: 'collide',
#  417: 'ebay',
#  418: 'phone',
#  419: 'bioterror',
#  420: 'shoulder',
#  421: 'airplane',
#  422: 'tonight',
#  423: 'goes',
#  424: 'part',
#  425: 'caused',
#  426: 'kids',
#  427: 'bush',
#  428: 'group',
#  429: '20',
#  430: 'drowned',
#  431: 'fan',
#  432: 'words',
#  433: 'suspect',
#  434: 'almost',
#  435: 'collision',
#  436: 'longer',
#  437: 'electrocuted',
#  438: 'traffic',
#  439: 'drown',
#  440: 'turkey',
#  441: 'soon',
#  442: 'demolished',
#  443: 'must',
#  444: 'devastation',
#  445: 'issues',
#  446: 'st',
#  447: 'hijacker',
#  448: 'tornado',
#  449: 'bombed',
#  450: 'reunion',
#  451: 'lets',
#  452: 'children',
#  453: 'lava',
#  454: 'song',
#  455: 'left',
#  456: 'stretcher',
#  457: 'avalanche',
#  458: 'security',
#  459: 'survivors',
#  460: 'volcano',
#  461: 'windstorm',
#  462: 'done',
#  463: 'light',
#  464: 'died',
#  465: 'n',
#  466: 'beautiful',
#  467: 'government',
#  468: 'upheaval',
#  469: 'thanks',
#  470: 'yeah',
#  471: 'chemical',
#  472: 'north',
#  473: 'building',
#  474: 'remember',
#  475: 'pic',
#  476: 'national',
#  477: 'three',
#  478: 'arson',
#  479: 'ur',
#  480: 'airport',
#  481: 'minute',
#  482: 'cyclone',
#  483: 'leave',
#  484: 'obliterate',
#  485: 'kill',
#  486: 'already',
#  487: 'annihilated',
#  488: 'music',
#  489: 'murderer',
#  490: 'bestnaijamade',
#  491: '9',
#  492: 'sue',
#  493: 'india',
#  494: 'due',
#  495: 'yet',
#  496: 'use',
#  497: 'inside',
#  498: 'screams',
#  499: 'bc',
#  500: 'blazing',
#  501: 'far',
#  502: 'obliteration',
#  503: 'tsunami',
#  504: 'declares',
#  505: 'guys',
#  506: 'market',
#  507: 'manslaughter',
#  508: 'shot',
#  509: 'hijacking',
#  510: 'helicopter',
#  511: 'shooting',
#  512: 'find',
#  513: 'land',
#  514: 'nearby',
#  515: 'peace',
#  516: 'battle',
#  517: 'hijack',
#  518: 'hours',
#  519: 'seismic',
#  520: 'razed',
#  521: 'play',
#  522: 'anything',
#  523: 'site',
#  524: 'line',
#  525: 'wait',
#  526: '6',
#  527: 'bioterrorism',
#  528: 'men',
#  529: '\x89ûó',
#  530: 'job',
#  531: 'hear',
#  532: 'crushed',
#  533: 'bigger',
#  534: 'outside',
#  535: 'deluged',
#  536: 'israeli',
#  537: 'send',
#  538: 'fun',
#  539: 'plans',
#  540: 'sirens',
#  541: 'demolition',
#  542: 'history',
#  543: 'tell',
#  544: 'river',
#  545: 'book',
#  546: 'policy',
#  547: 'rainstorm',
#  548: 'care',
#  549: 'islam',
#  550: 'days',
#  551: 'die',
#  552: 'probably',
#  553: 'theyre',
#  554: 'move',
#  555: 'zone',
#  556: '7',
#  557: 'nowplaying',
#  558: 'bar',
#  559: 're\x89û',
#  560: 'blaze',
#  561: 'media',
#  562: 'finally',
#  563: 'sound',
#  564: 'typhoondevastated',
#  565: 'saipan',
#  566: 'desolate',
#  567: 'yes',
#  568: 'rubble',
#  569: 'projected',
#  570: 'believe',
#  571: 'typhoon',
#  572: 'making',
#  573: '11yearold',
#  574: 'place',
#  575: 'eyewitness',
#  576: 'swallowed',
#  577: 'feared',
#  578: 'wake',
#  579: '8',
#  580: 'hell',
#  581: 'name',
#  582: 'brown',
#  583: 'watching',
#  584: 'bagging',
#  585: 'siren',
#  586: 'doesnt',
#  587: 'fight',
#  588: 'course',
#  589: 'lost',
#  590: 'gets',
#  591: 'deal',
#  592: 'business',
#  593: 'person',
#  594: 'reactor',
#  595: 'gun',
#  596: 'rise',
#  597: 'trench',
#  598: 'wont',
#  599: 'major',
#  600: 'horror',
#  601: 'conclusively',
#  602: 'ship',
#  603: 'control',
#  604: 'la',
#  605: 'reuters',
#  606: 'blight',
#  607: 'daily',
#  608: 'gt',
#  609: 'eyes',
#  610: 'used',
#  611: 'youth',
#  612: 'saved',
#  613: 'money',
#  614: 'anyone',
#  615: 'lab',
#  616: 'caught',
#  617: 'pick',
#  618: 'online',
#  619: 'searching',
#  620: 'officer',
#  621: 'casualty',
#  622: 'okay',
#  623: 'needs',
#  624: 'hey',
#  625: 'nearly',
#  626: 'signs',
#  627: 'side',
#  628: 'fast',
#  629: 'others',
#  630: 'refugio',
#  631: 'costlier',
#  632: 'ablaze',
#  633: 'angry',
#  634: 'huge',
#  635: 'crews',
#  636: 'west',
#  637: 'poor',
#  638: 'ago',
#  639: 'aircraft',
#  640: 'effect',
#  641: '30',
#  642: 'trying',
#  643: 'houses',
#  644: 'team',
#  645: 'cars',
#  646: 'space',
#  647: 'reason',
#  648: 'flash',
#  649: 'usa',
#  650: 'country',
#  651: 'snowstorm',
#  652: 'feeling',
#  653: 'support',
#  654: 'street',
#  655: 'self',
#  656: 'morning',
#  657: 'tv',
#  658: 'aug',
#  659: 'makes',
#  660: 'data',
#  661: 'south',
#  662: 'toddler',
#  663: 'running',
#  664: '13',
#  665: '60',
#  666: 'low',
#  667: 'memories',
#  668: 'might',
#  669: 'whats',
#  670: 'flag',
#  671: 'bodies',
#  672: 'womens',
#  673: '50',
#  674: 'ball',
#  675: 'order',
#  676: 'annihilation',
#  677: 'appears',
#  678: 'transport',
#  679: 'ignition',
#  680: 'knock',
#  681: '11',
#  682: 'crisis',
#  683: 'everything',
#  684: 'mp',
#  685: 'electrocute',
#  686: 'looking',
#  687: 'totally',
#  688: 'east',
#  689: 'case',
#  690: '12',
#  691: 'hate',
#  692: 'listen',
#  693: 'taking',
#  694: 'jobs',
#  695: 'russian',
#  696: 'abc',
#  697: 'trains',
#  698: 'win',
#  699: 'isnt',
#  700: 'second',
#  701: '10',
#  702: '25',
#  703: 'wrong',
#  704: 'american',
#  705: 'offensive',
#  706: 'amid',
#  707: 'damn',
#  708: 'spot',
#  709: 'blue',
#  710: 'public',
#  711: 'class',
#  712: 'center',
#  713: 'york',
#  714: 'action',
#  715: 'pay',
#  716: 'mph',
#  717: 'lord',
#  718: 'radio',
#  719: 'temple',
#  720: 'leather',
#  721: 'prebreak',
#  722: 'united',
#  723: 'pretty',
#  724: 'shes',
#  725: 'pakistan',
#  726: 'happy',
#  727: 'disea',
#  728: 'friends',
#  729: 'favorite',
#  730: 'closed',
#  731: 'guy',
#  732: 'theater',
#  733: 'nagasaki',
#  734: 'though',
#  735: 'govt',
#  736: 'camp',
#  737: 'till',
#  738: 'rock',
#  739: 'landing',
#  740: 'crazy',
#  741: 'issued',
#  742: 'entire',
#  743: 'photos',
#  744: 'turned',
#  745: 'seen',
#  746: 'chance',
#  747: 'stand',
#  748: 'sorry',
#  749: 'mayhem',
#  750: 'muslims',
#  751: 'picking',
#  752: 'soudelor',
#  753: '100',
#  754: 'four',
#  755: 'heavy',
#  756: 'gop',
#  757: 'unconfirmed',
#  758: 'neighbours',
#  759: 'banned',
#  760: 'reports',
#  761: 'hard',
#  762: 'ppl',
#  763: 'giant',
#  764: 'health',
#  765: 'view',
#  766: 'download',
#  767: 'hat',
#  768: 'link',
#  769: 'don\x89ûªt',
#  770: 'bbc',
#  771: 'madhya',
#  772: 'pradesh',
#  773: 'aftershock',
#  774: 'climate',
#  775: 'enough',
#  776: 'worst',
#  777: 'literally',
#  778: 'happened',
#  779: 'insurance',
#  780: 'property',
#  781: 'front',
#  782: 'thousands',
#  783: 'alone',
#  784: 'nws',
#  785: 'drive',
#  786: 'green',
#  787: 'wow',
#  788: 'downtown',
#  789: 'hailstorm',
#  790: 'declaration',
#  791: 'friend',
#  792: 'tweet',
#  793: 'date',
#  794: 'businesses',
#  795: 'russia',
#  796: 'mad',
#  797: 'aint',
#  798: 'playing',
#  799: 'upon',
#  800: 'trust',
#  801: 'gave',
#  802: 'seeing',
#  803: 'israel',
#  804: 'fukushima',
#  805: 'christian',
#  806: 'mount',
#  807: 'flight',
#  808: 'waves',
#  809: 'official',
#  810: 'sounds',
#  811: 'bed',
#  812: 'wanted',
#  813: 'couple',
#  814: 'large',
#  815: 'omg',
#  816: 'mop',
#  817: 'beach',
#  818: 'haha',
#  819: 'hollywood',
#  820: 'miners',
#  821: 'texas',
#  822: 'guess',
#  823: 'vehicle',
#  824: 'virgin',
#  825: 'colorado',
#  826: 'child',
#  827: 'moment',
#  828: 'mom',
#  829: 'myanmar',
#  830: 'called',
#  831: 'maybe',
#  832: 'star',
#  833: 'gas',
#  834: 'takes',
#  835: 'following',
#  836: 'wednesday',
#  837: 'thinking',
#  838: 'comes',
#  839: 'added',
#  840: 'town',
#  841: 'cut',
#  842: 'led',
#  843: 'lamp',
#  844: 'gbbo',
#  845: 'talk',
#  846: 'meek',
#  847: 'experts',
#  848: 'dog',
#  849: 'learn',
#  850: 'scared',
#  851: 'b',
#  852: 'london',
#  853: 'vs',
#  854: 'taken',
#  855: 'turn',
#  856: 'pamela',
#  857: 'level',
#  858: 'pakistani',
#  859: 'ladies',
#  860: 'cake',
#  861: 'centre',
#  862: 'film',
#  863: 'likely',
#  864: 'america',
#  865: 'libya',
#  866: 'instead',
#  867: 'pray',
#  868: 'global',
#  869: 'middle',
#  870: 'village',
#  871: 'reported',
#  872: 'reddits',
#  873: 'subreddits',
#  874: 'british',
#  875: 'scene',
#  876: 'hiring',
#  877: 'blizzard',
#  878: 'king',
#  879: 'driver',
#  880: 'germs',
#  881: 'anthrax',
#  882: 'mishaps',
#  883: 'biggest',
#  884: 'arsonist',
#  885: 'true',
#  886: 'series',
#  887: '05',
#  888: 'ready',
#  889: 'deep',
#  890: 'playlist',
#  891: 'break',
#  892: 'sad',
#  893: 'act',
#  894: 'lady',
#  895: 'financial',
#  896: 'falling',
#  897: 'arent',
#  898: 'told',
#  899: 'idea',
#  900: 'sex',
#  901: 'chinas',
#  902: 'gems',
#  903: 'risk',
#  904: 'potus',
#  905: 'quiz',
#  906: 'saying',
#  907: 'emmerdale',
#  908: 'album',
#  909: '70th',
#  910: 'china',
#  911: 'mode',
#  912: 'behind',
#  913: 'metal',
#  914: 'waving',
#  915: 'geller',
#  916: 'twelve',
#  917: 'safety',
#  918: 'room',
#  919: 'computers',
#  920: 'early',
#  921: 'hour',
#  922: 'wants',
#  923: 'try',
#  924: 'militants',
#  925: 'fans',
#  926: 'alarm',
#  927: 'awesome',
#  928: 'apollo',
#  929: 'marks',
#  930: 'bayelsa',
#  931: 'working',
#  932: 'truth',
#  933: 'human',
#  934: 'become',
#  935: 'give',
#  936: 'else',
#  937: 'earth',
#  938: 'drake',
#  939: 'escape',
#  940: 'devastated',
#  941: 'young',
#  942: 'france',
#  943: 'indian',
#  944: 'outrage',
#  945: 'former',
#  946: 'tree',
#  947: 'rd',
#  948: 'galactic',
#  949: 'coaches',
#  950: 'eye',
#  951: 'shift',
#  952: 'dance',
#  953: 'party',
#  954: 'wonder',
#  955: 'lake',
#  956: 'international',
#  957: 'miss',
#  958: 'took',
#  959: 'expected',
#  960: 'denver',
#  961: 'cree',
#  962: 'felt',
#  963: 'travel',
#  964: 'board',
#  965: 'niggas',
#  966: 'piece',
#  967: 'across',
#  968: 'hand',
#  969: 'aba',
#  970: 'delivers',
#  971: 'event',
#  972: 'ahead',
#  973: 'marians',
#  974: 'walk',
#  975: 'teen',
#  976: 'walking',
#  977: 'victims',
#  978: 'pain',
#  979: 'japanese',
#  980: 'nigga',
#  981: 'worse',
#  982: 'causes',
#  983: 'serious',
#  984: 'living',
#  985: 'fashion',
#  986: 'means',
#  987: 'patience',
#  988: 'jonathan',
#  989: 'bombs',
#  990: 'cdt',
#  991: 'cnn',
#  992: 'dude',
#  993: 'park',
#  994: 'join',
#  995: 'bring',
#  996: 'internet',
#  997: 'chile',
#  998: 'firefighters',
#  999: 'members',
#  1000: 'internally',
#  ...}

# %%
#decoding
def decode(sequence):
    return " ".join([reverse_word_index.get(idx, "?") for idx in sequence])

# %%
decoded_text = decode(train_sequences[10])
#Check
print(train_sequences[10])
print(decoded_text)
# Out:
# [1918, 1662, 1663, 208, 185, 5639, 647, 5640, 9, 5641, 5642]
# agreed especially automatic weapons theres legitimate reason needing one argus99 heidia1438

# %% [markdown]
# # 3- Modeling

# %%
# Create LSTM model

# Embedding: Turns positive integers (indexes) into dense vectors of fixed size.

model = keras.models.Sequential()
model.add(layers.Embedding(num_unique_words, 100, input_length=max_length))

model.add(layers.LSTM(32, dropout=0.25))
model.add(layers.Dense(1, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 15, 100)           1797100
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                17024
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 1,814,157
# Trainable params: 1,814,157
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss = keras.losses.BinaryCrossentropy(from_logits=False)
optim = keras.optimizers.Adam(learning_rate=0.001)
metrics = ["accuracy"]

model.compile(loss=loss, optimizer=optim, metrics=metrics)

# %%
model.fit(train_padded, train_labels, epochs=25, validation_data=(val_padded, val_labels), verbose=2)
# Out:
# Epoch 1/25
# 191/191 - 8s - loss: 0.5397 - accuracy: 0.7189 - val_loss: 0.4470 - val_accuracy: 0.8043
# Epoch 2/25
# 191/191 - 5s - loss: 0.2877 - accuracy: 0.8895 - val_loss: 0.5125 - val_accuracy: 0.7840
# Epoch 3/25
# 191/191 - 5s - loss: 0.1534 - accuracy: 0.9501 - val_loss: 0.5904 - val_accuracy: 0.7761
# Epoch 4/25
# 191/191 - 5s - loss: 0.0998 - accuracy: 0.9663 - val_loss: 0.6103 - val_accuracy: 0.7768
# Epoch 5/25
# 191/191 - 5s - loss: 0.0689 - accuracy: 0.9765 - val_loss: 0.6808 - val_accuracy: 0.7807
# Epoch 6/25
# 191/191 - 6s - loss: 0.0538 - accuracy: 0.9808 - val_loss: 0.7980 - val_accuracy: 0.7623
# Epoch 7/25
# 191/191 - 5s - loss: 0.0409 - accuracy: 0.9836 - val_loss: 0.9175 - val_accuracy: 0.7728
# Epoch 8/25
# 191/191 - 5s - loss: 0.0376 - accuracy: 0.9834 - val_loss: 1.1326 - val_accuracy: 0.7439
# Epoch 9/25
# 191/191 - 5s - loss: 0.0418 - accuracy: 0.9831 - val_loss: 1.0029 - val_accuracy: 0.7603
# Epoch 10/25
# 191/191 - 5s - loss: 0.0339 - accuracy: 0.9859 - val_loss: 1.3126 - val_accuracy: 0.7669
# Epoch 11/25
# 191/191 - 5s - loss: 0.0349 - accuracy: 0.9842 - val_loss: 1.0068 - val_accuracy: 0.7584
# Epoch 12/25
# 191/191 - 6s - loss: 0.0298 - accuracy: 0.9865 - val_loss: 1.2004 - val_accuracy: 0.7695
# Epoch 13/25
# 191/191 - 5s - loss: 0.0264 - accuracy: 0.9860 - val_loss: 1.3411 - val_accuracy: 0.7636
# Epoch 14/25
# 191/191 - 6s - loss: 0.0259 - accuracy: 0.9860 - val_loss: 1.4005 - val_accuracy: 0.7689
# Epoch 15/25
# 191/191 - 5s - loss: 0.0372 - accuracy: 0.9831 - val_loss: 1.1176 - val_accuracy: 0.7669
# Epoch 16/25
# 191/191 - 5s - loss: 0.0306 - accuracy: 0.9851 - val_loss: 1.2545 - val_accuracy: 0.7630
# Epoch 17/25
# 191/191 - 6s - loss: 0.0267 - accuracy: 0.9869 - val_loss: 1.3894 - val_accuracy: 0.7584
# Epoch 18/25
# 191/191 - 6s - loss: 0.0264 - accuracy: 0.9856 - val_loss: 1.4184 - val_accuracy: 0.7617
# Epoch 19/25
# 191/191 - 5s - loss: 0.0276 - accuracy: 0.9869 - val_loss: 1.2953 - val_accuracy: 0.7643
# Epoch 20/25
# 191/191 - 6s - loss: 0.0269 - accuracy: 0.9870 - val_loss: 1.3919 - val_accuracy: 0.7728
# Epoch 21/25
# 191/191 - 6s - loss: 0.0293 - accuracy: 0.9859 - val_loss: 1.1900 - val_accuracy: 0.7636
# Epoch 22/25
# 191/191 - 5s - loss: 0.0308 - accuracy: 0.9852 - val_loss: 1.2830 - val_accuracy: 0.7511
# Epoch 23/25
# 191/191 - 6s - loss: 0.0289 - accuracy: 0.9859 - val_loss: 1.4401 - val_accuracy: 0.7708
# Epoch 24/25
# 191/191 - 5s - loss: 0.0271 - accuracy: 0.9864 - val_loss: 1.2242 - val_accuracy: 0.7728
# Epoch 25/25
# 191/191 - 5s - loss: 0.0252 - accuracy: 0.9867 - val_loss: 1.5213 - val_accuracy: 0.7722

# %%
predictions = model.predict(test_padded)
predictions = [1 if p > 0.5 else 0 for p in predictions]

# %%
submission = pd.DataFrame({'id':test[['id','text']].values.tolist(),'target':predictions})

# %%
submission.sample(10)
# Out:
#                                                      id  target
# 1007  [3316, got wisdom teeth yesterday demolished w...       0
# 1814  [6136, apc needs watch pdp defecting apc patie...       1
# 681   [2208, something catastrophic coming tune via ...       1
# 2615                  [8731, heart sinking like sunset]       1
# 2094  [7028, tonight going mayhem 4playthursdays eve...       0
# 266   [862, fedex longer transport bioterror germs v...       0
# 2544  [8485, cokeboys yo best screamed watched snap ...       1
# 107              [362, new souls punished annihilation]       0
# 75    [250, twelve feared killed pakistani air ambul...       1
# 2259  [7511, california spring oil spill estimate gr...       1
